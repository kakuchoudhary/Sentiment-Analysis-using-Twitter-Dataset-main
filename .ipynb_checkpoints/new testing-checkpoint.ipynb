# %%
print("\033[1;32;43m Graphic Era Hill University \n Samarath Satyendra Choudhary  \n University Roll No. 2018023 \n")
# Out:
#  Graphic Era Hill University
#  Samarath Satyendra Choudhary
#  University Roll No. 2018023

# %%
# Import the libraries
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 # Import the libraries
# ----> 2 import tweepy
#       3 from textblob import TextBlob
#       4 from wordcloud import WordCloud
#
# ModuleNotFoundError: No module named 'tweepy'

# %%
twitterApiKey  =  'AMOcU2nMUsctzcO7Wo3PbvcFY'
twitterApiSecret =  '06g2Q53UrcgzMyJcKwC9DkK9zAxUcsSol6LAUUYEdxl0Z3Gwx9'
twitterApiAccessToken =  '746408181643902976-U4STPAKUmzf1Xuub8FkmiYigZkE0hQt'
twitterApiAccessTokenSecret =  'nH6PUfkBgl8BtWqJoG4H5ZTKtOx9tq1gqqrnXYCAGW1Mg'

# %%
auth=  tweepy.OAuthHandler(twitterApiKey,twitterApiSecret)
auth.set_access_token(twitterApiAccessToken,twitterApiAccessTokenSecret)
twitterApi  = tweepy.API(auth,wait_on_rate_limit = True)

# %%
twitterAccount = 'BillGates'

# %%
tweets  = tweepy.Cursor(twitterApi.user_timeline,
                        screen_name = twitterAccount,
                        count = None,
                        since_id = None,
                        max_id = None,trim_user = True,exclude_replies = True,contributor_details = False,
                        include_entitles=False).items(50);

# %%
df = pd.DataFrame(data=[tweet.text for tweet in tweets], columns = ['Tweet'])

# %%
df.head()
# Out:
#                                                Tweet
# 0  RT @gatesfoundation: As our CEO @MSuzman says,...
# 1                            https://t.co/padmHSgWGc
# 2  RT @WHO: The @ACTAccelerator, an unprecedented...
# 3  I was honored to speak at today’s #LeadersClim...
# 4  Ambitious short-term goals like this are criti...

# %%
def cleanUpTweet(txt):
    # Remove mentions
    txt = re.sub(r'@[A-Za-z0-9_]+', '', txt)
    # Remove hashtags
    txt = re.sub(r'#', '', txt)
    # Remove retweets:
    txt = re.sub(r'RT : ', '', txt)
    # Remove urls
    txt = re.sub(r'https?:\/\/[A-Za-z0-9\.\/]+', '', txt) 
    #removes stop words
    txt = re.sub(r'the', '', txt)
    txt = re.sub(r'and', '', txt)
    txt = re.sub(r'to', '', txt)
    return txt

# %%
df['Tweet'] = df['Tweet'].apply(cleanUpTweet)

# %%
def getTextSubjectivity(txt):
    return TextBlob(txt).sentiment.subjectivity

def getTextPolarity(txt):
    return TextBlob(txt).sentiment.polarity

# %%
df['Subjectivity']= df['Tweet'].apply(getTextSubjectivity)
df['Polarity']= df['Tweet'].apply(getTextPolarity)

# %%
df
# Out:
#                                                 Tweet  Subjectivity  Polarity
# 0   As our CEO  says, no barriers should st in  wa...      1.000000  0.500000
# 1                                                          0.000000  0.000000
# 2   The , an unprecedented global alliance  develo...      0.450000  0.300000
# 3   I was honored  speak at day’s LeadersClimateSu...      0.000000  0.000000
# 4   Ambitious short-term goals like this are criti...      0.558333  0.083333
# 5   It’s encouraging  see  Biden   Kerry re-establ...      0.000000  0.000000
# 6   Yesterday's verdict was a step in  right direc...      0.535714  0.285714
# 7   If “Time” wins  Oscar this year, it will be  f...      0.241667  0.095833
# 8   Communities of color have been hit hard by COV...      0.270833 -0.145833
# 9   In February, Ghana became  first African count...      0.166667  0.125000
# 10  To get  net-zero emissions globally by 2050, l...      0.000000  0.000000
# 11  Dr. Stephaun Wallace () has spent  last year h...      0.083333 -0.050000
# 12  The amount of cement China has consumed is a s...      0.200000  0.200000
# 13  Who installed  most concrete?\n\nCheck your an...      0.400000  0.325000
# 14  The best way  prevent new variants from emergi...      0.377273  0.568182
# 15  It's encouraging  see innovation  clean energy...      0.700000  0.366667
# 16  Here are five things you should know if you wa...      0.000000  0.000000
# 17  💡 From climateadaptation  genderequality, disc...      0.000000  0.000000
# 18  The technological transformation we need  addr...      0.533333  0.566667
# 19  I had a great time answering questions about m...      0.423737  0.312121
# 20  It's WorldTBDay\n\nEven as we battle COVID19, ...      0.000000  0.000000
# 21            I’m answering your questions now on :        0.000000  0.000000
# 22  In this video, I answered some really good que...      0.800000  0.550000
# 23  After you finish your pancakes this morning, c...      0.000000  0.000000
# 24  It’s deeply unfair that  people who contribute...      0.800000 -0.600000
# 25  Over  past few weeks health workers in Ethiopi...      0.175000 -0.225000
# 26  I named my book “How  Avoid a Climate Disaster...      0.000000  0.000000
# 27  Congratulations  on this important role. I’m e...      0.875000  0.387500
# 28  Thank you  for a great conversation about clim...      0.475000  0.500000
# 29  For decades, Australian researcher Ruth Bishop...      0.000000  0.000000
# 30  Speaking from villages, riverbanks  rural clin...      0.000000  0.000000
# 31  Virologist Ruth Bishop pioneered  research tha...      0.000000  0.000000
# 32  On International Women’s Day, join me in celeb...      0.666667  0.166667
# 33  Thank you  for  kind words. Your leadership at...      0.900000  0.600000
# 34  Black folks have questions about  COVID-19 vac...      0.385185 -0.162963
# 35  Moving  a green economy is  biggest challenge ...      0.300000 -0.200000
# 36  We can’t avoid a climate disaster without corp...      0.000000  0.000000
# 37  Delivering vaccines  those who need m most, no...      0.400000  0.278788
# 38  We're fortunate  have an Energy Secretary who'...      0.700000  0.383333
# 39  Recent extreme wear events are a stark reminde...      0.616667 -0.108333
# 40  Thanks    for a great conversation about how w...      0.475000  0.500000
# 41  I’m looking forward  joining   talk about clim...      0.000000  0.000000
# 42  It’s encouraging  have  John Kerry representin...      0.000000  0.000000
# 43  There are several ways individuals can help mo...      0.062500  0.000000
# 44  Thanks    for having me on  show  talk about c...      0.200000  0.200000
# 45  I’m grateful for new commitments from  EU, Ger...      0.584848  0.412121
# 46  I’m inspired by ’s activism  humanitarian work...      0.200000  0.200000
# 47  Meaningful action from business leaders will r...      0.366667  0.366667
# 48  Thanks  , ,  everyone who joined our virtual c...      0.200000  0.200000
# 49  Great  see this important step as  United Stat...      0.583333  0.400000

# %%
# word cloud visualization
allWords = ' '.join([twts for twts in df['Tweet']])
wordCloud = WordCloud(width=500, height=300, random_state=21, max_font_size=110).generate(allWords)


plt.imshow(wordCloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
def getTextAnalysis(a):
    if a < 0:
        return "Negative"
    elif a == 0:
        return "Neutral"
    else:
        return "Positive"

# %%
def getTextAnalysis(a):
    if a < 0:
        return "Negative"
    elif a == 0:
        return "Neutral"
    else:
        return "Positive"
#creates another column called Score and applies the function to the dataframe
df['Score'] = df['Polarity'].apply(getTextAnalysis)

# %%
df
# Out:
#                                                 Tweet  Subjectivity  Polarity  \
# 0   As our CEO  says, no barriers should st in  wa...      1.000000  0.500000
# 1                                                          0.000000  0.000000
# 2   The , an unprecedented global alliance  develo...      0.450000  0.300000
# 3   I was honored  speak at day’s LeadersClimateSu...      0.000000  0.000000
# 4   Ambitious short-term goals like this are criti...      0.558333  0.083333
# 5   It’s encouraging  see  Biden   Kerry re-establ...      0.000000  0.000000
# 6   Yesterday's verdict was a step in  right direc...      0.535714  0.285714
# 7   If “Time” wins  Oscar this year, it will be  f...      0.241667  0.095833
# 8   Communities of color have been hit hard by COV...      0.270833 -0.145833
# 9   In February, Ghana became  first African count...      0.166667  0.125000
# 10  To get  net-zero emissions globally by 2050, l...      0.000000  0.000000
# 11  Dr. Stephaun Wallace () has spent  last year h...      0.083333 -0.050000
# 12  The amount of cement China has consumed is a s...      0.200000  0.200000
# 13  Who installed  most concrete?\n\nCheck your an...      0.400000  0.325000
# 14  The best way  prevent new variants from emergi...      0.377273  0.568182
# 15  It's encouraging  see innovation  clean energy...      0.700000  0.366667
# 16  Here are five things you should know if you wa...      0.000000  0.000000
# 17  💡 From climateadaptation  genderequality, disc...      0.000000  0.000000
# 18  The technological transformation we need  addr...      0.533333  0.566667
# 19  I had a great time answering questions about m...      0.423737  0.312121
# 20  It's WorldTBDay\n\nEven as we battle COVID19, ...      0.000000  0.000000
# 21            I’m answering your questions now on :        0.000000  0.000000
# 22  In this video, I answered some really good que...      0.800000  0.550000
# 23  After you finish your pancakes this morning, c...      0.000000  0.000000
# 24  It’s deeply unfair that  people who contribute...      0.800000 -0.600000
# 25  Over  past few weeks health workers in Ethiopi...      0.175000 -0.225000
# 26  I named my book “How  Avoid a Climate Disaster...      0.000000  0.000000
# 27  Congratulations  on this important role. I’m e...      0.875000  0.387500
# 28  Thank you  for a great conversation about clim...      0.475000  0.500000
# 29  For decades, Australian researcher Ruth Bishop...      0.000000  0.000000
# 30  Speaking from villages, riverbanks  rural clin...      0.000000  0.000000
# 31  Virologist Ruth Bishop pioneered  research tha...      0.000000  0.000000
# 32  On International Women’s Day, join me in celeb...      0.666667  0.166667
# 33  Thank you  for  kind words. Your leadership at...      0.900000  0.600000
# 34  Black folks have questions about  COVID-19 vac...      0.385185 -0.162963
# 35  Moving  a green economy is  biggest challenge ...      0.300000 -0.200000
# 36  We can’t avoid a climate disaster without corp...      0.000000  0.000000
# 37  Delivering vaccines  those who need m most, no...      0.400000  0.278788
# 38  We're fortunate  have an Energy Secretary who'...      0.700000  0.383333
# 39  Recent extreme wear events are a stark reminde...      0.616667 -0.108333
# 40  Thanks    for a great conversation about how w...      0.475000  0.500000
# 41  I’m looking forward  joining   talk about clim...      0.000000  0.000000
# 42  It’s encouraging  have  John Kerry representin...      0.000000  0.000000
# 43  There are several ways individuals can help mo...      0.062500  0.000000
# 44  Thanks    for having me on  show  talk about c...      0.200000  0.200000
# 45  I’m grateful for new commitments from  EU, Ger...      0.584848  0.412121
# 46  I’m inspired by ’s activism  humanitarian work...      0.200000  0.200000
# 47  Meaningful action from business leaders will r...      0.366667  0.366667
# 48  Thanks  , ,  everyone who joined our virtual c...      0.200000  0.200000
# 49  Great  see this important step as  United Stat...      0.583333  0.400000
#
#        Score
# 0   Positive
# 1    Neutral
# 2   Positive
# 3    Neutral
# 4   Positive
# 5    Neutral
# 6   Positive
# 7   Positive
# 8   Negative
# 9   Positive
# 10   Neutral
# 11  Negative
# 12  Positive
# 13  Positive
# 14  Positive
# 15  Positive
# 16   Neutral
# 17   Neutral
# 18  Positive
# 19  Positive
# 20   Neutral
# 21   Neutral
# 22  Positive
# 23   Neutral
# 24  Negative
# 25  Negative
# 26   Neutral
# 27  Positive
# 28  Positive
# 29   Neutral
# 30   Neutral
# 31   Neutral
# 32  Positive
# 33  Positive
# 34  Negative
# 35  Negative
# 36   Neutral
# 37  Positive
# 38  Positive
# 39  Negative
# 40  Positive
# 41   Neutral
# 42   Neutral
# 43   Neutral
# 44  Positive
# 45  Positive
# 46  Positive
# 47  Positive
# 48  Positive
# 49  Positive

# %%
df['Score'].value_counts()
# Out:
# Positive    26
# Neutral     17
# Negative     7
# Name: Score, dtype: int64

# %%
print('Printing positive tweets:\n')
j=1
sortedDF = df.sort_values('Polarity') #Sort the tweets

for i in range(0, sortedDF.shape[0] ):
  if( sortedDF['Score'][i] == 'Positive'):
    print(str(j) + ') '+ sortedDF['Tweet'][i])
    print()
    j= j+1
# Out:
# Printing positive tweets:
#
# 1) As our CEO  says, no barriers should st in  way of equitable access  vaccines. We are supportive of a…
#
# 2) The , an unprecedented global alliance  develop &amp; deliver  tests, treatments &amp; vaccines  🌐 needs  fight …
#
# 3) Ambitious short-term goals like this are critical  moving closer  a net-zero future. As we rapidly scale  so…
#
# 4) Yesterday's verdict was a step in  right direction. But one court ruling alone will not bring  an end  inju…
#
# 5) If “Time” wins  Oscar this year, it will be  first documentary directed by a Black woman  do so. Garrett Br…
#
# 6) In February, Ghana became  first African country  receive vaccines through COVAX. Meet one of  nurses spearheading  v…
#
# 7) The amount of cement China has consumed is a staggering statistic  reminder of how much emissions have grown in…
#
# 8) Who installed  most concrete?
#
# Check your answer:
#
# 9) The best way  prevent new variants from emerging is by spping transmission of  virus alger:…
#
# 10) It's encouraging  see innovation  clean energy investments at  forefront of 's AmericanJobsPlan. Bui…
#
# 11) The technological transformation we need  address climate change can create good, safe jobs  build a more equi…
#
# 12) I had a great time answering questions about my new book, climate change,  COVID-19 on  last week. Here’s…
#
# 13) In this video, I answered some really good questions, including one about two really important numbers. Come ask me…
#
# 14) Congratulations  on this important role. I’m excited  see what you   Earth Fund will achieve…
#
# 15) Thank you  for a great conversation about climate change  thanks   …
#
# 16) On International Women’s Day, join me in celebrating some of  inspiring women who made COVID19 vaccines possible. Know…
#
# 17) Thank you  for  kind words. Your leadership at  2015 Paris climate conference helped prove that g…
#
# 18) Delivering vaccines  those who need m most, no matter where y live or how much money y have, is  only…
#
# 19) We're fortunate  have an Energy Secretary who's focused on creating high-quality jobs  build a clean energy eco…
#
# 20) Thanks    for a great conversation about how we can avoid a climate disaster.
#
# 21) Thanks    for having me on  show  talk about climate change  COVID-19 – two urgent…
#
# 22) I’m grateful for new commitments from  EU, Germany, Canada, Japan,   U.S.  help make safe  effective COVID-…
#
# 23) I’m inspired by ’s activism  humanitarian work. Thanks     for hosti…
#
# 24) Meaningful action from business leaders will require  courage  take risks that many companies aren't used  t…
#
# 25) Thanks  , ,  everyone who joined our virtual conversation about climate change.…
#
# 26) Great  see this important step as  United States resumes our global leadership on climate change. Looking forw…

# %%
print('Printing negative tweets:\n')
j=1
sortedDF = df.sort_values('Polarity',ascending=False) #Sort the tweets
for i in range(0, sortedDF.shape[0] ):
  if( sortedDF['Score'][i] == 'Negative'):
    print(str(j) + ') '+sortedDF['Tweet'][i])
    print()
    j=j+1
# Out:
# Printing negative tweets:
#
# 1) Communities of color have been hit hard by COVID-19. One of  reasons why parts of  medical system often fail…
#
# 2) Dr. Stephaun Wallace () has spent  last year helping make COVID-19 vaccines work for everybody.…
#
# 3) It’s deeply unfair that  people who contribute  least  climate change will suffer  worst from its effect…
#
# 4) Over  past few weeks health workers in Ethiopia 🇪🇹, Nigeria 🇳🇬, Sudan 🇸🇩   Philippines 🇵🇭 were vaccinated against COVI…
#
# 5) Black folks have questions about  COVID-19 vaccine. I sat down w/ Black healthcare workers &amp; y answered my questions.…
#
# 6) Moving  a green economy is  biggest challenge  world has ever faced. I’m optimistic we can do it, but need…
#
# 7) Recent extreme wear events are a stark reminder that we’re already seeing  effects of climate change here at…

# %%
# Plotting 
plt.figure(figsize=(8,6)) 
for i in range(0, df.shape[0]):
  plt.scatter(df["Polarity"][i], df["Subjectivity"][i], color='Blue') 
# plt.scatter(x,y,color)   
plt.title('Sentiment Analysis') 
plt.xlabel('Polarity') 
plt.ylabel('Subjectivity') 
plt.show()

# %%
positive = df[df['Score'] == 'Positive']
print(str(positive.shape[0]/(df.shape[0])*100) + " % of positive tweets")
pos = (positive.shape[0]/(df.shape[0])*100)
positive = df[df['Score'] == 'Neutral']
print(str(positive.shape[0]/(df.shape[0])*100) + " % of neutral tweets")
neu = (positive.shape[0]/(df.shape[0])*100)
positive = df[df['Score'] == 'Negative']
print(str(positive.shape[0]/(df.shape[0])*100) + " % of negative tweets")
neg = (positive.shape[0]/(df.shape[0])*100)
# Out:
# 52.0 % of positive tweets
# 34.0 % of neutral tweets
# 14.000000000000002 % of negative tweets

# %%
explode = (0,0.1,0)
labels = 'Positive','Negative','Neutral'
sizes =  [pos,neg,neu]
colors = ['lime', 'red', 'blue']
plt.pie(sizes,explode= explode,colors=colors,autopct='%1.1f%%',startangle =120)
plt.legend(labels,loc = (-0.5,0.05), shadow=True)
plt.axis('equal')
# Out:
# (-1.1131931104581128,
#  1.1925496676068823,
#  -1.1093077194201255,
#  1.1023503280850442)

# %%
labels = df.groupby('Score').count().index.values
values = df.groupby('Score').size().values
plt.bar(labels, values, color = ['red', 'blue', 'lime'])
plt.title(label = " Sentiment Analysis ", 
                  fontsize = '15')
# Out:
# Text(0.5, 1.0, ' Sentiment Analysis ')
